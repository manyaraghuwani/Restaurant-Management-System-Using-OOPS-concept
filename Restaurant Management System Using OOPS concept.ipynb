# %%
class PythonCafeTalk:
    def __init__(rp):
        print("\t\t\t\t Python Cafe Talk")
        print("\t\t\t\t Since-1997")
        print("\t\t\t\t www.fuddybuddy.com")
        print("\n\n\t\t\t\t\tMENU")
        
        x=["Indian","German","Korean","Vietnamese"]
        for k in x:
            print("\n\n",k)
    def german(rp):
        x=["Sauerbraten-roas beef stew ","Schweinshaxe-pork knuckle","Rinderroulade-beef roll","Bratwurst-grilled sausage","Kartoffelpuffer-potato pancake","Kartoffelkloesse-potato dumplings","Sauerkraut-fermented cabbage","Spatzle-Egg noodles"]
        y=[250,300,150,100,200,100,350,180]
        german_={"German Food Types":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(german_)
        print("\n\n German Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position : "))
            c=int(input("Enter the Quantity:"))
            z=german_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print('Thank you')
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
        
        
    def korean(rp):
        x=["Kimchi","Bibimbap","Bulgogi","Jajangmyeon","Samgyeopsal","Korean fried chicken","Red rice cakes - tteokbokki"]
        y=[200,100,350,400,100,345,250]
        korean_={"Korean Food Types":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(korean_)
        print("\n\n Korean Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position : "))
            c=int(input("Enter the Quantity:"))
            z=korean_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print('Thank you')
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
        
    
        
        
    def vietnamese(rp):
        x=["Pho","Bun cha","Banh mi","Banh cuon","Goi cuon"]
        y=[250,300,200,100,500]
        vietnamese_={"Vietnamese Food Types":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(vietnamese_)
        print("\n\n Vietnamese Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position : "))
            c=int(input("Enter the Quantity:"))
            z=vietnamese_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print('Thank you')
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
        
    
        
    def indian(rp):
        x=["Misal Pav","Kosha Mangsho","Makki Di Roti& sarso da saag","Dhokla","Rogan Josh","Papaya Khar","Litti Chowkha","Biryani","Fish Curry"]
        y=[80,200,350,120,200,150,250,400,500]
        indian_={"Indian Food Types":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(indian_)
        print("\n\n Indian Foods \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the value position : "))
            c=int(input("Enter the Quantity:"))
            z=indian_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print('Thank you')
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")

# %%
obj=PythonCafeTalk()
# Out:
# 				 Python Cafe Talk
# 				 Since-1997
# 				 www.fuddybuddy.com
#
#
# 					MENU
#
#
#  Indian
#
#
#  German
#
#
#  Korean
#
#
#  Vietnamese

# %%
x=input("Enter the Type of food : ")
if x=="indian":
    print(obj.indian())
elif x=="german":
    print(obj.german())
elif x=="korean":
    print(obj.korean())
elif x=="vietnamese":
    print(obj.vietnamese())
else:
    print("wrong option: \nplease again choose the right option:")
# Out:
# Enter the Type of food : indian
#
#
#  Indian Foods
#
#
#               Indian Food Types  Price
# 0                     Misal Pav     80
# 1                 Kosha Mangsho    200
# 2  Makki Di Roti& sarso da saag    350
# 3                        Dhokla    120
# 4                    Rogan Josh    200
# 5                   Papaya Khar    150
# 6                 Litti Chowkha    250
# 7                       Biryani    400
# 8                    Fish Curry    500
# Enter the value position : 7
# Enter the Quantity:3
# you want to reorder(yes/no):yes
# Enter the value position : 8
# Enter the Quantity:2
# you want to reorder(yes/no):yes
# Enter the value position : 3
# Enter the Quantity:5
# you want to reorder(yes/no):no
# Thank you
# servicetax = 5%
# Total Amount: 2800 Rupees
# Total Amount Including Service Tax: 2940.0 Rupees
# None

# %%
class PythonCafeTalk:
    def __init__(rp):
        print("\t\t\t\t Python Cafe Talk")
        print("\t\t\t\t Since-1997")
        print("\t\t\t\t www.fuddybuddy.com")
        print("\n\n\t\t\t\t\tMENU")
        
        x=["Indian","German","Korean","Vietnamese"]
        for k in x:
            print("\n\n",k)

# %%
obj=PythonCafeTalk()
# Out:
# 				 Python Cafe Talk
# 				 Since-1997
# 				 www.fuddybuddy.com
#
#
# 					MENU
#
#
#  Indian
#
#
#  German
#
#
#  Korean
#
#
#  Vietnamese

# %%
a=input()
b=input()
add=a+b
print(add,type(add))
# Out:
# 45
# 55
# 4555 <class 'str'>

# %%
fname=input("Enter the first name:")
lname=input("Enter the last name:")
name=fname+lname
print(name,type(name))
# Out:
# Enter the first name:Rohan
# Enter the last name:Sharma
# RohanSharma <class 'str'>

# %%
fname=input("Enter the first name:")
lname=input("Enter the last name:")
name=fname+lname
print(name,type(name))
# Out:
# Enter the first name:Rohan
# Enter the last name:Sharma
# Rohan Sharma <class 'str'>

# %%
fname=input("Enter the first name:")
lname=input("Enter the last name:")
name=fname+lname
print(name,type(name))
# Out:
# Enter the first name:Rohan
# Enter the last name: Sharma
# Rohan Sharma <class 'str'>

# %%
fname=input("Enter the first name:")
lname=input("Enter the last name:")
name=fname+" "+lname
print(name,type(name))
# Out:
# Enter the first name:Rohan
# Enter the last name:Sharma
# Rohan Sharma <class 'str'>

# %%
a=input("Enter the value of a:")
b=input("Enter the value of b:")
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:55
# Enter the value of b:6
# 556 <class 'str'>

# %%
a=int(input("Enter the value of a:"))
b=int(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:45
# Enter the value of b:12
# 57 <class 'int'>

# %%
a=int(input("Enter the value of a:"))
b=int(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:45.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a=int(input("Enter the value of a:"))
#       2 b=int(input("Enter the value of b:"))
#       3 add=a+b
#
# ValueError: invalid literal for int() with base 10: '45.5'

# %%
a=float(input("Enter the value of a:"))
b=float(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:45.5
# Enter the value of b:55.6
# 101.1 <class 'float'>

# %%
a=float(input("Enter the value of a:"))
b=float(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:10
# Enter the value of b:5
# 15.0 <class 'float'>

# %%
a
# Out:
# 10.0

# %%
b
# Out:
# 5.0

# %%
a=complex(input("Enter the value of a:"))
b=complex(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:4+10j
# Enter the value of b:6+5j
# (10+15j) <class 'complex'>

# %%
a=complex(input("Enter the value of a:"))
b=complex(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:5
# Enter the value of b:10+6j
# (15+6j) <class 'complex'>

# %%
a
# Out:
# (5+0j)

# %%
a=eval(input("Enter the value of a:"))
b=eval(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:10
# Enter the value of b:15.5
# 25.5 <class 'float'>

# %%
a
# Out:
# 10

# %%
b
# Out:
# 15.5

# %%
a=eval(input("Enter the value of a:"))
b=eval(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:"Sumit"
# Enter the value of b:"Jain"
# SumitJain <class 'str'>

# %%
a=eval(input("Enter the value of a:"))
b=eval(input("Enter the value of b:"))
add=a+b
print(add,type(add))
# Out:
# Enter the value of a:sumit
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 a=eval(input("Enter the value of a:"))
#       2 b=eval(input("Enter the value of b:"))
#       3 add=a+b
#
# File <string>:1
#
# NameError: name 'sumit' is not defined
